# %% [markdown]
# IPL / Sports data analysis
# Analyze match / player CSVs to get top
# scorers, strike rates, team win rates.
# Visualize per-season and per-player
# metrics.
# Compare player performance across
# seasons.
# Export visual summary and short insights.
